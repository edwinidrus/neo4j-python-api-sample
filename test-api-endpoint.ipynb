# %%
import requests

# %%
import requests


url = "http://localhost:8000/playlists"
payload = {
    "title": "The Hives Best Of",
    "songs": ["7r68k5cbrF0GiFGSY538MW", "05pYGBaNqoIqsy5FjsnL1o"]
}
headers = {
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 500
# Internal Server Error

# %%
url = "http://localhost:8000/artist_creation"
payload = {
    "uid": "000111",
    "name": "hellow_ngukb baba",
    "songs" : []
}
headers = {
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"uid":"6a57a29ca01446469961c36a8eac6e16","name":"hellow_ngukb baba","songs":[]}

# %%
url = "http://localhost:8000/album_creation"
payload = {
    "uid": "000111"
    # "name": "hellow_ngukb baba",
    # "songs" : []
}
headers = {
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"uid":"0ea34a2c264e4295be60cb35a96c050e"}

# %%
url = "http://localhost:8000/search_artist"
payload = {
    # "uid": "000111"
    "artist_name": "hellow_ngukb baba"
    # "songs" : []
}
headers = {
    "Content-Type": "application/json"
}

response = requests.get(url, json=payload, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 500
# Internal Server Error

# %%
# url = "http://localhost:8000/artists/"
# payload = {
#     # "uid": "000111",
#     "page_size": 5,
#     "page_number": 1
# }
# headers = {
#     "Content-Type": "application/json"
# }

# response = requests.get(url, 
# # json=payload, 
# headers=headers)

# print(response.status_code)
# print(response.text)
# Out:
# 500
# Internal Server Error
