# %%
### for the neomodel prototype ###

"""
The module provides classes for representing music data in a Neo4j database using neomodel.

Classes:
- Album: Represents an album in the music database.
- Song: Represents a song in the music database.
- Artist: Represents an artist in the music database.
- Playlist: Represents a playlist in the music database.

Dependencies:
- neomodel: The module relies on the neomodel library for interacting with the Neo4j database.
"""

from neomodel import (
    StructuredNode,
    StringProperty,
    IntegerProperty,
    FloatProperty,
    BooleanProperty,
    RelationshipTo,
    ZeroOrMore,
    OneOrMore,
    UniqueIdProperty,
)


class Album(StructuredNode):
    """
    An album is represented only by its unique identifier.

    Properties:
    - uid: str

    Relationships: None
    """

    uid = UniqueIdProperty()


class Song(StructuredNode):
    """
    A song has a title and musical characteristics defined by Spotify.

    It is released in at least one album.

    Properties:
    - uid: str
    - title: str
    - ... see class

    Relationships:
    - albums: One or more
    """

    uid = UniqueIdProperty()
    title = StringProperty(index=True)
    loudness = FloatProperty()
    liveness = FloatProperty()
    tempo = FloatProperty()
    valence = FloatProperty()
    instrumentalness = FloatProperty()
    danceability = FloatProperty()
    speechiness = FloatProperty()
    duration = IntegerProperty()
    mode = BooleanProperty()
    popularity = IntegerProperty()
    acousticness = FloatProperty()
    key = IntegerProperty()
    energy = FloatProperty()

    albums = RelationshipTo(Album, "RELEASED_IN", cardinality=OneOrMore)


class Artist(StructuredNode):
    """
    An artist has a name, and can have recorded songs.

    Properties:
    - uid: str
    - name: str

    Relationships:
    - songs: Zero or more
    """

    uid = UniqueIdProperty()
    name = StringProperty(index=True)

    songs = RelationshipTo(Song, "RECORDED", cardinality=ZeroOrMore)


class Playlist(StructuredNode):
    """
    A playlist has a title, and at least one song.

    Properties:
    - uid: str
    - title: str

    Relationships:
    - songs: One or more
    """

    uid = UniqueIdProperty()
    title = StringProperty(index=True)

    songs = RelationshipTo(Song, "CONTAINS", cardinality=OneOrMore)

# %%
"""Configuration parameters"""
from neomodel import config

# config.DATABASE_URL = "bolt://neo4j:password@localhost:7687/spotify"
config.DATABASE_URL = "neo4j+s://neo4j:CwYoDsImGeIEDHLurmbrd_qWxwrX5TIwzNeBP9fjaCo@f95431fe.databases.neo4j.io"

# %%
Artist.nodes.all()
# Out:
# [<Artist: {'uid': '7FBcuc1gsnv6Y1nwFtNRCb', 'name': None, 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:9227'}>,
#  <Artist: {'uid': '7oPftvlwr6VrsViSDV7fJY', 'name': None, 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:9228'}>,
#  <Artist: {'uid': '5LfGQac0EIXyAN8aUwmNAQ', 'name': None, 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:9229'}>,
#  <Artist: {'uid': '3Ayl7mCk0nScecqOzvNp6s', 'name': None, 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:9230'}>,
#  <Artist: {'uid': '6TIYQ3jFPwQSRmorSezPxX', 'name': None, 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:9231'}>,
#  <Artist: {'uid': '4UXqAaa6dQYAk18Lv7PEgX', 'name': None, 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:9232'}>,
#  <Artist: {'uid': '46gyXjRIvN1NL1eCB8GBxo', 'name': None, 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:9233'}>,
# ...

# %%
artist = Artist.nodes.get(uid="3zxKH0qp3nBCuPZCZT5Vaf")
artist
# Out:
# <Artist: {'uid': '3zxKH0qp3nBCuPZCZT5Vaf', 'name': None, 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:9251'}>

# %%
Artist(uid='cilukba-weleh', name ="baleg_seloh", songs = [] ).save()
# Out:
# <Artist: {'songs': [], 'uid': 'cilukba-weleh', 'name': 'baleg_seloh', 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:11226'}>

# %%
artist_filtered = Artist.nodes.filter(uid__icontains='cilukba')
artist_filtered.all()
# Out:
# [<Artist: {'uid': 'cilukba-weleh', 'name': 'baleg_seloh', 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:11226'}>]

# %%
all_song = Song.nodes.all()
all_song
# Out:
# [<Song: {'uid': '7j31rVgGX9Q2blT92VBEA0', 'title': 'Teenagers', 'loudness': -3.063, 'liveness': 0.184, 'tempo': 111.647, 'valence': 0.856, 'instrumentalness': 0.0, 'danceability': 0.463, 'speechiness': 0.0632, 'duration': 161920, 'mode': True, 'popularity': 81, 'acousticness': 0.0506, 'key': 4, 'energy': 0.857, 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:61'}>,
#  <Song: {'uid': '6L89mwZXSOwYl76YXfX13s', 'title': 'Basket Case', 'loudness': -3.205, 'liveness': 0.091, 'tempo': 85.064, 'valence': 0.781, 'instrumentalness': 8.71e-06, 'danceability': 0.442, 'speechiness': 0.0602, 'duration': 181533, 'mode': True, 'popularity': 81, 'acousticness': 0.00293, 'key': 3, 'energy': 0.943, 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:62'}>,
# ...

# %%
song_filtered = Song.nodes.filter(title__icontains='blitzkrieg')
song_filtered.all()
# Out:
# [<Song: {'uid': '4KcH1ZRV2W1q7Flq0QqC76', 'title': 'Blitzkrieg Bop - 2016 Remaster', 'loudness': -2.533, 'liveness': 0.108, 'tempo': 176.701, 'valence': 0.902, 'instrumentalness': 0.47, 'danceability': 0.385, 'speechiness': 0.233, 'duration': 134466, 'mode': True, 'popularity': 73, 'acousticness': 0.000269, 'key': 9, 'energy': 0.783, 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:72'}>,
#  <Song: {'uid': '68YFOeWusWCFxK4TSYZZBU', 'title': 'Blitzkrieg Bop', 'loudness': -10.19, 'liveness': 0.392, 'tempo': 200.476, 'valence': 0.677, 'instrumentalness': 0.0063, 'danceability': 0.249, 'speechiness': 0.0332, 'duration': 125000, 'mode': True, 'popularity': 35, 'acousticness': 0.0225, 'key': 9, 'energy': 0.962, 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:3388'}>]

# %%
Song.nodes.get(uid="4KcH1ZRV2W1q7Flq0QqC76").title
# Out:
# 'Blitzkrieg Bop - 2016 Remaster'

# %%
Album.nodes.all()
# Out:
# [<Album: {'uid': '0FZK97MXMm5mUQ8mtudjuK', 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:5480'}>,
#  <Album: {'uid': '4uG8q3GPuWHQlRbswMIRS6', 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:5481'}>,
#  <Album: {'uid': '67v63ubEsvDUQkYMzI7A9t', 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:5482'}>,
#  <Album: {'uid': '0UJhhj5bn5AGAjryFnhueP', 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:5483'}>,
#  <Album: {'uid': '57lgFncHBYu5E3igZnuCJK', 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:5484'}>,
#  <Album: {'uid': '0hHopYqXhuvYSHtVyrcb1g', 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:5485'}>,
#  <Album: {'uid': '0H4ELcHequ3OligrjWfrZP', 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:5486'}>,
#  <Album: {'uid': '3DuiGV3J09SUhvp8gqNx8h', 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:5487'}>,
# ...

# %%
Album(uid='0029348414').save()
# Out:
# <Album: {'uid': '0029348414', 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:11225'}>

# %%
Album.nodes.get(uid='0029348414')
# Out:
# <Album: {'uid': '0029348414', 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:11225'}>

# %%
import requests

# %%
import requests


url = "http://localhost:8000/playlists"
payload = {
    "title": "The Hives Best Of",
    "songs": ["7r68k5cbrF0GiFGSY538MW", "05pYGBaNqoIqsy5FjsnL1o"]
}
headers = {
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 500
# Internal Server Error

# %%
url = "http://localhost:8000/artist_creation"
payload = {
    "uid": "Hellow-herder 110928384",
    "name": "Balegsellow",
    "songs" : []
}
headers = {
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"uid":"Hellow-herder 110928384","name":"Balegsellow","songs":[]}

# %% [markdown]
# ## for the template of Post and PUt Methode

# %%
url = "http://localhost:8000/album_creation"
payload = {
    "uid": "000111"
    # "name": "hellow_ngukb baba",
    # "songs" : []
}
headers = {
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 500
# Internal Server Error

# %%
url = "http://localhost:8000/search_artist"
payload = {
    "uid": "000111",
    "artist_name": "hellow_ngukb baba",
    "songs" : []
}
headers = {
    "Content-Type": "application/json"
}

response = requests.get(url, json=payload, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 500
# Internal Server Error

# %%
# url = "http://localhost:8000/artists/"
# payload = {
#     # "uid": "000111",
#     "page_size": 5,
#     "page_number": 1
# }
# headers = {
#     "Content-Type": "application/json"
# }

# response = requests.get(url, 
# # json=payload, 
# headers=headers)

# print(response.status_code)
# print(response.text)
# Out:
# 500
# Internal Server Error

# %% [markdown]
# ## For the Request with Get Method - template

# %%
import requests

url = "http://localhost:8000/function_test"
params = {
    "uid": "cilukba-weleh",
    "name": "baleg_seloh",
    "songs": []  # or ["song1", "song2"] if needed
}
response = requests.get(url, params=params)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"uid":"cilukba-weleh","name":"baleg_seloh","songs":[]}

# %%
### searching artist

import requests

url = "http://localhost:8000/search_artist_test"
params = {
    "uid": "Hellow-herder 110928384",
    "name": "Balegsellow"  # or ["song1", "song2"] if needed
}
response = requests.get(url, params=params)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"uid":"Hellow-herder 110928384","name":"Balegsellow"}

# %%
Artist.nodes.get(uid="Hellow-herder 110928384")
# Out:
# <Artist: {'uid': 'Hellow-herder 110928384', 'name': 'Balegsellow', 'element_id_property': '4:2989d916-620c-4520-8ff8-0e92b1c7b295:11227'}>

# %%
filtered = Artist.nodes.filter(uid__icontaints="110928384" )
filtered
